# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/churn.csv")
df.head()
# Out:
# Matplotlib is building the font cache; this may take a moment.
#    customerID  tenure  MonthlyCharges        Contract     PaymentMethod  \
# 0        1001       1              70  Month-to-month  Electronic check
# 1        1002      24              55        One year       Credit card
# 2        1003      12              90  Month-to-month  Electronic check
# 3        1004      60              40        Two year     Bank transfer
# 4        1005       6              80  Month-to-month  Electronic check
#
#   TechSupport Churn
# 0          No   Yes
# 1         Yes    No
# 2          No   Yes
# 3         Yes    No
# 4          No   Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerID      8 non-null      int64
#  1   tenure          8 non-null      int64
#  2   MonthlyCharges  8 non-null      int64
#  3   Contract        8 non-null      object
#  4   PaymentMethod   8 non-null      object
#  5   TechSupport     8 non-null      object
#  6   Churn           8 non-null      object
# dtypes: int64(3), object(4)
# memory usage: 580.0+ bytes

# %%
sns.countplot(x="Churn", data=df)
plt.show()

# %%
sns.boxplot(x="Churn", y="MonthlyCharges", data=df)
plt.show()
